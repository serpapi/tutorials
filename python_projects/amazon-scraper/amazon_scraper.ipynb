# %% [markdown]
# # Amazon Product Scraper - Step by Step Guide
#
# This notebook demonstrates how to scrape Amazon product information step by step. We'll extract:
# - Product Names
# - Star Ratings
# - Number of Ratings
# - Prices
#
# Let's start by importing the necessary libraries.

# %%
# Import Required Libraries
import requests
import json
import csv
from bs4 import BeautifulSoup
import re

# %% [markdown]
# Here we set up the Amazon search URL and headers to mimic a real browser request.

# %%
# Define Search Parameters
url = "https://www.amazon.com/s/........" # Add your search URL here

payload = {}
headers = {
    # This value is intentionally left blank. Make sure to fill it in with actual headers from Postman to mimic a real browser request.
}

# %%
# Make the GET Request
response = requests.request("GET", url, headers=headers, data=payload)

print(f"Status Code: {response.status_code}")
print(f"Response Length: {len(response.text)} characters")

if response.status_code == 200:
    print("Request successful!")
else:
    print("Request failed!")
# Out:
# Status Code: 200
# Response Length: 1734724 characters
# Request successful!

# %%
# Parse HTML with BeautifulSoup
soup = BeautifulSoup(response.text, 'html.parser')

# Find all product containers
product_containers = soup.find_all('div', {'data-component-type': 's-search-result'})

print(f"Found {len(product_containers)} product containers")
# Out:
# Found 48 product containers

# %%
container = product_containers[0]
product_name = container.find('h2').get_text(strip=True)
print("Product Name:", product_name)
# Out:
# Product Name: Folgers Classic Roast Medium Roast Ground Coffee, 33.7 Ounces (Pack of 6)

# %%
review_block = container.find('div', {'data-cy': 'reviews-block'})

# %%
star_rating = review_block.find('span', {'class': 'a-size-small'}).get_text(strip=True)
number_of_reviews = review_block.find('div', {'data-csa-c-content-id': 'alf-customer-ratings-count-component'}).find('a').get('aria-label')

print("Star Rating:", star_rating, "stars")
print("Number of Ratings:", number_of_reviews)
# Out:
# Star Rating: 4.8 stars
# Number of Ratings: 2,020 ratings

# %%
price = container.find('span', {'class': 'a-offscreen'}).get_text(strip=True)
print("Price: $", price)
# Out:
# Price: $ $77.84

# %%
def extract_all_products():
    products = []
    
    for container in product_containers:
        product = {}
        
        # Extract Product Name
        name_element = container.find('h2')
        if name_element:
            product['product_name'] = name_element.get_text(strip=True)
        else:
            product['product_name'] = 'N/A'
        
        # Extract Stars Rating and Number of Reviews
        review_block = container.find('div', {'data-cy': 'reviews-block'})
        if review_block:
            # Extract star rating
            star_rating_element = review_block.find('span', {'class': 'a-size-small'})
            if star_rating_element:
                rating_text = star_rating_element.get_text(strip=True)
                rating_match = re.search(r'(\d+\.?\d*)', rating_text)
                product['star_rating'] = rating_match.group(1) if rating_match else 'N/A'
            else:
                product['star_rating'] = 'N/A'
            
            # Extract number of reviews
            reviews_element = review_block.find('div', {'data-csa-c-content-id': 'alf-customer-ratings-count-component'})
            if reviews_element:
                reviews_link = reviews_element.find('a')
                if reviews_link:
                    reviews_text = reviews_link.get('aria-label', '')
                    reviews_match = re.search(r'([\d,]+)', reviews_text)
                    product['num_rating'] = reviews_match.group(1) if reviews_match else 'N/A'
                else:
                    product['num_rating'] = 'N/A'
            else:
                product['num_rating'] = 'N/A'
        else:
            product['star_rating'] = 'N/A'
            product['num_rating'] = 'N/A'
        
        # Extract Price
        price_element = container.find('span', {'class': 'a-offscreen'})
        if price_element:
            price_text = price_element.get_text(strip=True)
            # Clean up the price text (remove extra $ symbols)
            price_clean = price_text.replace('$', '').strip()
            product['price'] = price_clean if price_clean else 'N/A'
        else:
            product['price'] = 'N/A'
        
        # Only add products that have at least a name
        if product['product_name'] != 'N/A':
            products.append(product)
    
    return products

def save_to_csv(products, filename='amazon_products.csv'):
    """Save products data to CSV file"""
    if not products:
        print("No products to save!")
        return
    
    # Define CSV fieldnames
    fieldnames = ['product_name', 'star_rating', 'num_rating', 'price']
    
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(products)
    
    print(f"Data saved to {filename}")

# Extract all products
all_products = extract_all_products()

# Save to CSV
save_to_csv(all_products)

# Display results
print(f"Found {len(all_products)} products:")
print("=" * 80)
for i, product in enumerate(all_products, 1):
    print(f"{i}. {product['product_name']}")
    print(f"   Star Rating: {product['star_rating']} stars")
    print(f"   Number of Ratings: {product['num_rating']}")
    print(f"   Price: ${product['price']}")
    print("-" * 80)
# Out:
# Data saved to amazon_products.csv
# Found 48 products:
# ================================================================================
# 1. Folgers Classic Roast Medium Roast Ground Coffee, 33.7 Ounces (Pack of 6)
#    Star Rating: 4.8 stars
#    Number of Ratings: 2,020
#    Price: $77.84
# --------------------------------------------------------------------------------
# 2. Nespresso Capsules Vertuo, Variety Pack, Medium and Dark Roast Coffee, 30 Count Coffee Pods, Brews 7.8 oz.
#    Star Rating: 4.8 stars
#    Number of Ratings: 122,801
#    Price: $43.08
# --------------------------------------------------------------------------------
# 3. Peet's Coffee, Dark Roast Single Serve Coffee Pods - Major Dickason's Blend 75 Count (1 Box of 75 Pods)
#    Star Rating: 4.7 stars
#    Number of Ratings: 57,331
#    Price: $42.98
# --------------------------------------------------------------------------------
# 4. Maxwell House 27.5oz Ground Coffee Medium Original Roast
#    Star Rating: 4.7 stars
#    Number of Ratings: 20,923
#    Price: $12.97
# --------------------------------------------------------------------------------
# 5. The Original Donut Shop Regular Keurig Single-Serve K-Cup Pods, Medium Roast Coffee, 72 Count
#    Star Rating: 4.7 stars
#    Number of Ratings: 81,776
#    Price: $40.48
# --------------------------------------------------------------------------------
# 6. McCafe Premium Roast Coffee, Keurig Single Serve K-Cup Pods, Medium Roast, 96 Count
#    Star Rating: 4.7 stars
#    Number of Ratings: 59,369
#    Price: $45.94
# --------------------------------------------------------------------------------
# 7. Lavazza Super Crema Whole Bean Coffee, Medium Espresso Roast, Arabica and Robusta Blend, 2.2 lb Bag, Package May Vary (Pack of 1)
#    Star Rating: 4.5 stars
#    Number of Ratings: 35,466
#    Price: $23.80
# --------------------------------------------------------------------------------
# 8. Folgers Classic Roast Ground Coffee (51 oz.), 2 Pack (Limited Edition)
#    Star Rating: 4.4 stars
#    Number of Ratings: 1,053
#    Price: $59.99
# --------------------------------------------------------------------------------
# 9. Dunkin' Original Blend Medium Roast Ground Coffee, 30 Ounce
#    Star Rating: 4.8 stars
#    Number of Ratings: 8,971
#    Price: $17.97
# --------------------------------------------------------------------------------
# 10. Maxwell House 28.4oz Ground Coffee Medium Wake Up Roast
#    Star Rating: 4.7 stars
#    Number of Ratings: 9,207
#    Price: $11.99
# --------------------------------------------------------------------------------
# 11. McCafe Premium Medium Roast Ground Coffee (24 oz Canister)
#    Star Rating: 4.7 stars
#    Number of Ratings: 29,033
#    Price: $12.47
# --------------------------------------------------------------------------------
# 12. Amazon Fresh, Colombia Ground Coffee, Medium Roast, 32 Oz
#    Star Rating: 4.3 stars
#    Number of Ratings: 20,673
#    Price: $15.36
# --------------------------------------------------------------------------------
# 13. Amazon Brand - Happy Belly Medium Roast Coffee Pods, Donut Style, Compatible with Keurig 2.0 K-Cup Brewers, 100 Count
#    Star Rating: 4.3 stars
#    Number of Ratings: 83,509
#    Price: $34.81
# --------------------------------------------------------------------------------
# 14. Maxwell House Original Roast Ground Coffee, 33.1 oz Canister
#    Star Rating: 4.7 stars
#    Number of Ratings: 1,018
#    Price: $18.01
# --------------------------------------------------------------------------------
# 15. Maxwell House House Blend Medium Roast K-Cup Coffee Pods, 84 ct Box
#    Star Rating: 4.7 stars
#    Number of Ratings: 48,377
#    Price: $37.78
# --------------------------------------------------------------------------------
# 16. Eight O'Clock Coffee The Original Ground Coffee, Medium Roast, 32 Ounce (Pack of 1) - Sweet, Fruity, Well Balanced
#    Star Rating: 4.6 stars
#    Number of Ratings: 23,043
#    Price: $14.47
# --------------------------------------------------------------------------------
# 17. Starbucks Ground Coffee, Medium Roast Coffee, Pike Place Roast, 100% Arabica, 1 Bag (28 Oz)
#    Star Rating: 4.6 stars
#    Number of Ratings: 31,075
#    Price: $20.97
# --------------------------------------------------------------------------------
# 18. Crave Beverages Flavored Coffee Pods Sampler, Compatible with 2.0 K-Cup Brewers, Assorted Variety Pack, 100 Count
#    Star Rating: 4.4 stars
#    Number of Ratings: 52,090
#    Price: $39.90
# --------------------------------------------------------------------------------
# 19. Victor Allen's Coffee Variety Pack (Morning Blend, 100% Colombian, Donut Shop Blend, and Italian Roast), 80 Count, Single Serve Coffee Pods for Keurig K-Cup Brewers
#    Star Rating: 4.4 stars
#    Number of Ratings: 83,247
#    Price: $37.39
# --------------------------------------------------------------------------------
# 20. Amazon Brand - Solimo Dark Roast Coffee Pods, Compatible with Keurig 2.0 K-Cup Brewers 100 Count(Pack of 1)
#    Star Rating: 4.3 stars
#    Number of Ratings: 181,850
#    Price: $41.65
# --------------------------------------------------------------------------------
# 21. Amazon Fresh, Colombia Whole Bean Coffee Medium Roast, 32 Oz
#    Star Rating: 4.3 stars
#    Number of Ratings: 13,551
#    Price: $15.69
# --------------------------------------------------------------------------------
# 22. Green Mountain Coffee Roasters Dark Magic Coffee, Keurig Single-Serve K-Cup pods, Dark Roast, 96 Count
#    Star Rating: 4.7 stars
#    Number of Ratings: 36,917
#    Price: $51.46
# --------------------------------------------------------------------------------
# 23. Seattle's Best Coffee Portside Blend Medium Roast Ground Coffee | 12 Ounce Bags (Pack of 6)
#    Star Rating: 4.5 stars
#    Number of Ratings: 8,673
#    Price: $44.82
# --------------------------------------------------------------------------------
# 24. Green Mountain Coffee Roasters Colombia Select Coffee, Keurig Single-Serve K-Cup Pods, Medium Roast Coffee, 96 Count
#    Star Rating: 4.7 stars
#    Number of Ratings: 48,000
#    Price: $51.96
# --------------------------------------------------------------------------------
# 25. New England Coffee Breakfast Blend Medium Roast Ground Coffee, 12oz Bag (Pack of 1)
#    Star Rating: 4.5 stars
#    Number of Ratings: 27,735
#    Price: $5.43
# --------------------------------------------------------------------------------
# 26. Maxwell House Dark Silk Dark Roast Ground Coffee, 24.5 oz Canister
#    Star Rating: 4.6 stars
#    Number of Ratings: 46,941
#    Price: $12.99
# --------------------------------------------------------------------------------
# 27. Starbucks K-Cup Coffee Pods, Medium Roast Coffee, Pike Place Roast for Keurig Brewers, 100% Arabica, 6 boxes (60 pods total)
#    Star Rating: 4.6 stars
#    Number of Ratings: 75,853
#    Price: $41.00
# --------------------------------------------------------------------------------
# 28. Starbucks Ground Coffee, Starbucks Blonde Roast Coffee, Veranda Blend, 100% Arabica, 1 bag (28 oz)
#    Star Rating: 4.6 stars
#    Number of Ratings: 11,363
#    Price: $20.97
# --------------------------------------------------------------------------------
# 29. Starbucks K-Cup Coffee Pods, Starbucks Blonde Roast Coffee, Veranda Blend for Keurig Brewers, 100% Arabica, 4 boxes (96 pods total)
#    Star Rating: 4.7 stars
#    Number of Ratings: 27,627
#    Price: $59.97
# --------------------------------------------------------------------------------
# 30. Starbucks Ground Coffee, Dark Roast Coffee, Italian Roast, 100% Arabica, 1 bag (18 oz)
#    Star Rating: 4.7 stars
#    Number of Ratings: 60,369
#    Price: $9.63
# --------------------------------------------------------------------------------
# 31. Don Francisco's Hawaiian Hazelnut Ground Flavored Coffee: Rich, Aromatic 100% Arabica Beans - (3 x 12 oz Recyclable Cans)
#    Star Rating: 4.6 stars
#    Number of Ratings: 14,526
#    Price: $23.01
# --------------------------------------------------------------------------------
# 32. Newman's Own Organics Special Blend Keurig Single-Serve K-Cup Pods, Medium Roast Coffee, 96 Count
#    Star Rating: 4.6 stars
#    Number of Ratings: 20,134
#    Price: $52.79
# --------------------------------------------------------------------------------
# 33. Eight O'Clock Coffee Colombian Peaks Keurig Single-Serve K-Cup Pods, Medium Roast Coffee, 96 Count (Pack of 4)
#    Star Rating: 4.7 stars
#    Number of Ratings: 29,315
#    Price: $49.99
# --------------------------------------------------------------------------------
# 34. Eight O'Clock Coffee The Original Whole Bean Coffee, Medium Roast, 40 Ounce (Pack of 1) - Sweet, Fruity, Well Balanced
#    Star Rating: 4.6 stars
#    Number of Ratings: 16,975
#    Price: $16.98
# --------------------------------------------------------------------------------
# 35. Community Coffee Breakfast Blend 72 Ounces Ground Coffee, Medium Roast, 12 Ounce Bag (Pack of 6)
#    Star Rating: 4.6 stars
#    Number of Ratings: 12,747
#    Price: $35.94
# --------------------------------------------------------------------------------
# 36. Caribou Coffee, Light Roast Ground Coffee - Daybreak Morning Blend 20 Ounce Bag - Packaging May Vary
#    Star Rating: 4.6 stars
#    Number of Ratings: 10,811
#    Price: $10.94
# --------------------------------------------------------------------------------
# 37. Starbucks K-Cup Coffee Pods, Dark Roast Coffee, Sumatra for Keurig Brewers, 100% Arabica, 4 boxes (96 pods total)
#    Star Rating: 4.7 stars
#    Number of Ratings: 46,368
#    Price: $59.97
# --------------------------------------------------------------------------------
# 38. Community Coffee Breakfast Blend, Medium Roast, Single-Serve Keurig K-Cup Pods, 72 Count (Pack of 1)
#    Star Rating: 4.6 stars
#    Number of Ratings: 27,789
#    Price: $35.94
# --------------------------------------------------------------------------------
# 39. Tim Horton's 100% Arabica Dark Roast, Ground Coffee, 12 Ounce
#    Star Rating: 4.6 stars
#    Number of Ratings: 16,281
#    Price: $5.98
# --------------------------------------------------------------------------------
# 40. Starbucks Dark Roast Ground Coffee, Variety Pack, 3 bags (12 oz each)
#    Star Rating: 4.6 stars
#    Number of Ratings: 5,378
#    Price: $47.97
# --------------------------------------------------------------------------------
# 41. Green Mountain Coffee Roasters Breakfast Blend Decaf Coffee, Keurig Single Serve K-Cup pods, Light Roast, 96 Count
#    Star Rating: 4.7 stars
#    Number of Ratings: 49,391
#    Price: $51.82
# --------------------------------------------------------------------------------
# 42. McCafe Premium Roast, Keurig Single Serve K-Cup Pods, Medium Roast Coffee Pods, 32 Count
#    Star Rating: 4.7 stars
#    Number of Ratings: 21,141
#    Price: $17.99
# --------------------------------------------------------------------------------
# 43. Illy Whole Bean Coffee, Classico Medium Roast - Mild & Balanced - 100% Arabica - Whole Beans - Pressurized Packaging Sealed for Freshness - 8.8oz can (Pack of 6)
#    Star Rating: 4.4 stars
#    Number of Ratings: 9,530
#    Price: $71.94
# --------------------------------------------------------------------------------
# 44. Cameron's Coffee Roasted Ground Coffee Bag, Flavored, Toasted Southern Pecan, 12 Ounce (Pack of 6)
#    Star Rating: 4.5 stars
#    Number of Ratings: 9,572
#    Price: $36.63
# --------------------------------------------------------------------------------
# 45. Cafe La Llave Cuban-Style Espresso Dark Roast Ground Coffee, 8-Pack (7 x 10 oz + 1 Bonus Cafe Gaviña), Rich and Bold
#    Star Rating: 4.8 stars
#    Number of Ratings: 1,067
#    Price: $39.98
# --------------------------------------------------------------------------------
# 46. Folgers Classic Roast Filter Packs, Premeasured Ground Coffee and Filter in a Single Pouch, 160 Count (Pack of 4)
#    Star Rating: 4.7 stars
#    Number of Ratings: 218
#    Price: $156.10
# --------------------------------------------------------------------------------
# 47. Café Bustelo Espresso Style Dark Roast Coffee, 72 Count Keurig K-Cup Pods
#    Star Rating: 4.8 stars
#    Number of Ratings: 28,480
#    Price: $39.98
# --------------------------------------------------------------------------------
# 48. Café Bustelo Espresso Dark Roast Ground Coffee Brick, 10 Ounce (Pack of 12)
#    Star Rating: 4.8 stars
#    Number of Ratings: 3,757
#    Price: $65.04
# --------------------------------------------------------------------------------
